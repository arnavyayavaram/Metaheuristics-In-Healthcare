# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'dataset' is your dataset where each row represents an image
# 'selected_pixels' is an array indicating selected pixels (1D array of indices)
# 'index' is the row index representing the image you want to visualize

# Example dataset (replace this with your actual dataset)
# dataset = ... (your dataset here)
# selected_pixels = ... (your array of selected pixel indices)
# index = 0  # Change this index to select a different image

# Example dataset generation (for demonstration purposes)
np.random.seed(42)
dataset = np.random.randint(0, 256, size=(100, 784))  # Generating a dummy dataset of 100 images

index = 0  # Selecting the first image for visualization

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
# Load the MNIST dataset
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist.data, mnist.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# c:\Users\siddh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
# Define an index for the dataset
index = 3

# Extract the image from the dataset and reshape it to 28x28
image = X_train.iloc[index].values.reshape(28, 28)

# Indices of the selected pixels
selected_pixels = np.array([432, 318, 327, 484, 184, 182, 353, 372, 434, 625, 265, 515, 350, 481, 518, 656, 237, 241, 595, 289, 244, 130, 154, 439, 541, 321, 324, 149])

# Create an array to store the selected pixels
selected_image = np.zeros_like(image)
selected_image.flat[selected_pixels] = image.flat[selected_pixels]

# Plot the original and selected images
plt.figure(figsize=(8, 4))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

# # Selected Pixels Highlighted Image
# plt.subplot(1, 2, 2)
# plt.imshow(selected_image, cmap='gray')
# plt.title('Selected Pixels Highlighted')

plt.show()

# %%
# Define an index for the dataset
index = 5

# Indices of the selected pixels
selected_pixels = np.array([669, 373, 550, 727, 213, 161, 569, 349, 270, 433, 404, 148, 459,
       288, 346, 647, 209, 436, 256, 412, 323, 443, 495, 318, 236, 357,
       247, 486])

# Create an array to store the selected pixels
selected_mask = np.zeros((28, 28))

# Set the selected pixels to 1 in the mask
selected_mask.flat[selected_pixels] = 1

# Plot the selected pixels
plt.imshow(selected_mask, cmap='gray')
plt.title('Selected Pixels')
plt.show()

# %%
# Define an index for the dataset
index = 5

# Indices of the selected pixels
selected_pixels = np.array([669, 373, 550, 727, 213, 161, 569, 349, 270, 433, 404, 148, 459,
       288, 346, 647, 209, 436, 256, 412, 323, 443, 495, 318, 236, 357,
       247, 486])

# Create an array to store the selected pixels
selected_mask = np.zeros((28, 28))

# Set the selected pixels to 1 in the mask
selected_mask.flat[selected_pixels] = 1

# Plot the selected pixels
plt.imshow(selected_mask, cmap='gray')
plt.title('Selected Pixels')
plt.show()

# %%
randomly = np.random.choice(784, 28, replace=False)

# Create an array to store the selected pixels
selected_mask = np.zeros((28, 28))

# Set the selected pixels to 1 in the mask
selected_mask.flat[randomly] = 1

# Plot the selected pixels
plt.imshow(selected_mask, cmap='gray')
plt.title('Selected Pixels')
plt.show()
